# %% [markdown]
# # RunaGen AI - Exploratory Data Analysis
# ## Job Market & Skills Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path

sns.set_style('whitegrid')

# %% [markdown]
# ## Load Bronze Layer Data

# %%
# Load job postings
bronze_path = Path('../data/bronze/adzuna')
# TODO: Load and analyze data

# %% [markdown]
# ## Skill Frequency Analysis

# %%
# Analyze most in-demand skills

# %% [markdown]
# ## Salary Distribution by Role

# %%
# Visualize salary distributions
